# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

import time
import numpy as np
import pandas as pd

# Set webdriver options
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('ignore-certificate-errors')

#close any opened driver
try:
    driver.close() 
except Exception:
    pass

# Initiate webdriver
driver = webdriver.Chrome(r'C:\Users\josep\Desktop\Capstone 4\Data\chromedriver', options=options)

#indicate scraping start page
start_page = 206
last_page = 228

url = f'https://www.99.co/singapore/rent/condos-apartments'
driver.get(url+f'?page_num={start_page}')

# %%
def get_link_in_page():

    """
    Get all the house link in for a given page
    """
    links = driver.find_elements_by_xpath("//div[@class='_2kH6B']//a[contains(@href,'')]")
    house_links = [link.get_attribute("href") for link in links]
    return house_links

# %%
# WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.XPATH, '//*[@id="appContent"]/div/div[3]/div[1]/div/div[4]/ul/li[8]/a')))
# last_page = driver.find_element_by_xpath('//*[@id="appContent"]/div/div[3]/div[1]/div/div[4]/ul/li[8]/a').text
# last_page = int(last_page)

# %%
def scrape_one_listing(link):
    
    listing_detailed = dict()
    # WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.XPATH, '//*[@id="price"]/h2')))
    
    class_name = '_2sIc2 _29qfj _2rhE-'
    WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.XPATH, f'//*[@class="{class_name}"]')))

    
    listing_detailed['link'] = link
    #main header
    try:listing_detailed['price_month'] = driver.find_element_by_xpath('//*[@id="price"]/h2').text
    except:listing_detailed['price_month'] = np.nan
    
 
    #Property details
    elems = driver.find_elements_by_xpath(f"//p[@class='_2sIc2 _29qfj _2rhE-']")    
    details = [elem.text.split(" ") for elem in elems]
    for sub_list in details:
        if len(sub_list) == 1:
            listing_detailed[f"{sub_list[0].lower()}"] = sub_list[0].lower() # This is to cater to Studio label
        else:
            listing_detailed[f"{sub_list[1].lower()}"] = sub_list[0] # Catering to the other property details e.g. no. of baths


    # try:listing_detailed['bedroom'] = driver.find_elements_by_xpath(f'//p[@class="{class_name}"]')[0].text
    # except:listing_detailed['bedroom'] =  np.nan
    
    # try:listing_detailed['bathroom'] = driver.find_elements_by_xpath(f'//p[@class="{class_name}"]')[1].text
    # except:listing_detailed['bathroom'] =  np.nan
    
    # try:listing_detailed['sqft'] = driver.find_elements_by_xpath(f'//p[@class="{class_name}"]')[2].text
    # except:listing_detailed['sqft'] =  np.nan


    try:listing_detailed['detailed_address'] = driver.find_element_by_xpath('//*[@id="overview"]/div/div[2]/div[1]/p/span[1]').text
    except:listing_detailed['detailed_address'] =  np.nan

    try:listing_detailed['district'] = driver.find_element_by_xpath('//*[@id="overview"]/div/div[2]/div[1]/p/span[3]').text
    except:listing_detailed['district'] =  np.nan

    #property details
    # This section will take into account these details (if present): Availability, Lease, Furnishing, Property Type, 
    # Name, Unit Types, Total Units, Built Year, Tenure, Developer, and Neighbourhood
    class_name_td1 = '_3r4yN NomDX'
    class_name_td2 = '_3r4yN XCAFU'
    num_of_property_details = len(driver.find_elements_by_xpath(f"//div[contains(@class, '{class_name_td1}')]"))
    for i in range(num_of_property_details):
        detail_category = driver.find_elements_by_xpath(f"//div[contains(@class, '{class_name_td1}')]")[i].text
        detail_category = detail_category.lower()
        detail_category = detail_category.replace(" ","_")
        listing_detailed[f'{detail_category}'] = driver.find_elements_by_xpath(f"//div[@class='{class_name_td2}']")[i].text    
    #picture url

    try:listing_detailed['picture_url'] = driver.find_element_by_xpath('//*[@id="listingPageContent"]/div[1]/div[1]/div[2]/div/div[1]/img').get_attribute('src')
    except:listing_detailed['picture_url'] = np.nan
    
    #mrt
    try:
        listing_detailed['mrt_distance'] = driver.find_element_by_xpath('//*[@id="listingPageContent"]/div[1]/div[1]/div[1]/div[2]/p/span').text
        listing_detailed['mrt_name'] = driver.find_element_by_xpath('//*[@id="listingPageContent"]/div[1]/div[1]/div[1]/div[2]/p/a').text
    except:
        listing_detailed['mrt_distance'] = np.nan
        listing_detailed['mrt_name'] = np.nan
        
    #Amenities
    # Expand amenities
    try:
        driver.find_element_by_xpath('//*[@id="listingPageContent"]/div[1]/div[1]/div[3]/button/span').click()
    
    #wait until button expanded 
        WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.XPATH, '//*[@id="listingPageContent"]/div[1]/div[1]/div[3]/button')))
    except: pass
    #extractall amenities
    amenities_elems = driver.find_elements_by_xpath("//p[@class='_2sIc2 _2rhE-']")
    try: listing_detailed['amenities'] = [ele.text for ele in amenities_elems]
    except: listing_detailed['amenities'] = np.nan
    
    #scroll down to load map element

    # for i in range(1,5):
    #     driver.execute_script(f"window.scrollBy(0,{i*200})","")
    #     time.sleep(0.5)
    

    # map_element = driver.find_element_by_xpath('//*[@id="location"]')
    
    # actions = ActionChains(driver)
    # actions.move_to_element(map_element).perform()
    # time.sleep(1)

    #extract distance to key location
    # class_name_location_div = '_3OnRG'
    # class_name_location = 'yMCxv _1YwzE _1vzK2'
    # try: listing_detailed['travel_time_changi'] = driver.find_elements_by_xpath(f"//div[@class='{class_name_location_div}']/h4[@class='{class_name_location}']")[0].text
    # except: listing_detailed['travel_time_changi'] = np.nan
    
    # try:listing_detailed['travel_time_raffles'] = driver.find_elements_by_xpath(f"//div[@class='{class_name_location_div}']/h4[@class='{class_name_location}']")[1].text
    # except: listing_detailed['travel_time_raffles'] = np.nan
    
    # try:listing_detailed['travel_time_orchard'] = driver.find_elements_by_xpath(f"//div[@class='{class_name_location_div}']/h4[@class='{class_name_location}']")[2].text
    # except: listing_detailed['travel_time_orchard'] = np.nan
    
    return listing_detailed

# %%
#
try:
    scraped_df = pd.read_csv('scraped_df3.csv')
    print("Existing Data Found")
except:
    scraped_df = pd.DataFrame()

for _ in range(start_page, last_page+1):
    current_page = WebDriverWait(driver, 30).until(expected_conditions.presence_of_element_located((By.XPATH, "//li[@class='active']"))).text
    current_page = int(current_page)
    print(current_page)
    if current_page <= last_page:
        links = get_link_in_page()
        for pg, link in enumerate(links):
            driver.get(link)
            listing_dict = scrape_one_listing(link)
            scraped_df = scraped_df.append(listing_dict, ignore_index=True)
            time.sleep(0.5)
            print(f"Completed {pg+1} out of {len(links)} links of Page {current_page}")
        start_page = start_page + 1
        print("Next Page is ", start_page)
        scraped_df.to_csv('scraped_df3.csv', index=False)
        driver.get(url+f'?page_num={start_page}')
# Out:
# Existing Data Found
# 206
# Completed 1 out of 35 links of Page 206
# Completed 2 out of 35 links of Page 206
# Completed 3 out of 35 links of Page 206
# Completed 4 out of 35 links of Page 206
# Completed 5 out of 35 links of Page 206
# Completed 6 out of 35 links of Page 206
# Completed 7 out of 35 links of Page 206
# Completed 8 out of 35 links of Page 206
# Completed 9 out of 35 links of Page 206
# Completed 10 out of 35 links of Page 206
# Completed 11 out of 35 links of Page 206
# Completed 12 out of 35 links of Page 206
# Completed 13 out of 35 links of Page 206
# Completed 14 out of 35 links of Page 206
# Completed 15 out of 35 links of Page 206
# Completed 16 out of 35 links of Page 206
# Completed 17 out of 35 links of Page 206
# Completed 18 out of 35 links of Page 206
# Completed 19 out of 35 links of Page 206
# Completed 20 out of 35 links of Page 206
# Completed 21 out of 35 links of Page 206
# Completed 22 out of 35 links of Page 206
# Completed 23 out of 35 links of Page 206
# Completed 24 out of 35 links of Page 206
# Completed 25 out of 35 links of Page 206
# Completed 26 out of 35 links of Page 206
# Completed 27 out of 35 links of Page 206
# Completed 28 out of 35 links of Page 206
# Completed 29 out of 35 links of Page 206
# Completed 30 out of 35 links of Page 206
# Completed 31 out of 35 links of Page 206
# Completed 32 out of 35 links of Page 206
# Completed 33 out of 35 links of Page 206
# Completed 34 out of 35 links of Page 206
# Completed 35 out of 35 links of Page 206
# Next Page is  207
# 207
# Completed 1 out of 35 links of Page 207
# Completed 2 out of 35 links of Page 207
# Completed 3 out of 35 links of Page 207
# Completed 4 out of 35 links of Page 207
# Completed 5 out of 35 links of Page 207
# Completed 6 out of 35 links of Page 207
# Completed 7 out of 35 links of Page 207
# Completed 8 out of 35 links of Page 207
# Completed 9 out of 35 links of Page 207
# Completed 10 out of 35 links of Page 207
# Completed 11 out of 35 links of Page 207
# Completed 12 out of 35 links of Page 207
# Completed 13 out of 35 links of Page 207
# Completed 14 out of 35 links of Page 207
# Completed 15 out of 35 links of Page 207
# Completed 16 out of 35 links of Page 207
# Completed 17 out of 35 links of Page 207
# Completed 18 out of 35 links of Page 207
# Completed 19 out of 35 links of Page 207
# Completed 20 out of 35 links of Page 207
# Completed 21 out of 35 links of Page 207
# Completed 22 out of 35 links of Page 207
# Completed 23 out of 35 links of Page 207
# Completed 24 out of 35 links of Page 207
# Completed 25 out of 35 links of Page 207
# Completed 26 out of 35 links of Page 207
# Completed 27 out of 35 links of Page 207
# Completed 28 out of 35 links of Page 207
# Completed 29 out of 35 links of Page 207
# Completed 30 out of 35 links of Page 207
# Completed 31 out of 35 links of Page 207
# Completed 32 out of 35 links of Page 207
# Completed 33 out of 35 links of Page 207
# Completed 34 out of 35 links of Page 207
# Completed 35 out of 35 links of Page 207
# Next Page is  208
# 208
# Completed 1 out of 35 links of Page 208
# Completed 2 out of 35 links of Page 208
# Completed 3 out of 35 links of Page 208
# Completed 4 out of 35 links of Page 208
# Completed 5 out of 35 links of Page 208
# Completed 6 out of 35 links of Page 208
# Completed 7 out of 35 links of Page 208
# Completed 8 out of 35 links of Page 208
# Completed 9 out of 35 links of Page 208
# Completed 10 out of 35 links of Page 208
# Completed 11 out of 35 links of Page 208
# Completed 12 out of 35 links of Page 208
# Completed 13 out of 35 links of Page 208
# Completed 14 out of 35 links of Page 208
# Completed 15 out of 35 links of Page 208
# Completed 16 out of 35 links of Page 208
# Completed 17 out of 35 links of Page 208
# Completed 18 out of 35 links of Page 208
# Completed 19 out of 35 links of Page 208
# Completed 20 out of 35 links of Page 208
# Completed 21 out of 35 links of Page 208
# Completed 22 out of 35 links of Page 208
# Completed 23 out of 35 links of Page 208
# Completed 24 out of 35 links of Page 208
# Completed 25 out of 35 links of Page 208
# Completed 26 out of 35 links of Page 208
# Completed 27 out of 35 links of Page 208
# Completed 28 out of 35 links of Page 208
# Completed 29 out of 35 links of Page 208
# Completed 30 out of 35 links of Page 208
# Completed 31 out of 35 links of Page 208
# Completed 32 out of 35 links of Page 208
# Completed 33 out of 35 links of Page 208
# Completed 34 out of 35 links of Page 208
# Completed 35 out of 35 links of Page 208
# Next Page is  209
# 209
# Completed 1 out of 35 links of Page 209
# Completed 2 out of 35 links of Page 209
# Completed 3 out of 35 links of Page 209
# Completed 4 out of 35 links of Page 209
# Completed 5 out of 35 links of Page 209
# Completed 6 out of 35 links of Page 209
# Completed 7 out of 35 links of Page 209
# Completed 8 out of 35 links of Page 209
# Completed 9 out of 35 links of Page 209
# Completed 10 out of 35 links of Page 209
# Completed 11 out of 35 links of Page 209
# Completed 12 out of 35 links of Page 209
# Completed 13 out of 35 links of Page 209
# Completed 14 out of 35 links of Page 209
# Completed 15 out of 35 links of Page 209
# Completed 16 out of 35 links of Page 209
# Completed 17 out of 35 links of Page 209
# Completed 18 out of 35 links of Page 209
# Completed 19 out of 35 links of Page 209
# Completed 20 out of 35 links of Page 209
# Completed 21 out of 35 links of Page 209
# Completed 22 out of 35 links of Page 209
# Completed 23 out of 35 links of Page 209
# Completed 24 out of 35 links of Page 209
# Completed 25 out of 35 links of Page 209
# Completed 26 out of 35 links of Page 209
# Completed 27 out of 35 links of Page 209
# Completed 28 out of 35 links of Page 209
# Completed 29 out of 35 links of Page 209
# Completed 30 out of 35 links of Page 209
# Completed 31 out of 35 links of Page 209
# Completed 32 out of 35 links of Page 209
# Completed 33 out of 35 links of Page 209
# Completed 34 out of 35 links of Page 209
# Completed 35 out of 35 links of Page 209
# Next Page is  210
# 210
# Completed 1 out of 35 links of Page 210
# Completed 2 out of 35 links of Page 210
# Completed 3 out of 35 links of Page 210
# Completed 4 out of 35 links of Page 210
# Completed 5 out of 35 links of Page 210
# Completed 6 out of 35 links of Page 210
# Completed 7 out of 35 links of Page 210
# Completed 8 out of 35 links of Page 210
# Completed 9 out of 35 links of Page 210
# Completed 10 out of 35 links of Page 210
# Completed 11 out of 35 links of Page 210
# Completed 12 out of 35 links of Page 210
# Completed 13 out of 35 links of Page 210
# Completed 14 out of 35 links of Page 210
# Completed 15 out of 35 links of Page 210
# Completed 16 out of 35 links of Page 210
# Completed 17 out of 35 links of Page 210
# Completed 18 out of 35 links of Page 210
# Completed 19 out of 35 links of Page 210
# Completed 20 out of 35 links of Page 210
# Completed 21 out of 35 links of Page 210
# Completed 22 out of 35 links of Page 210
# Completed 23 out of 35 links of Page 210
# Completed 24 out of 35 links of Page 210
# Completed 25 out of 35 links of Page 210
# Completed 26 out of 35 links of Page 210
# Completed 27 out of 35 links of Page 210
# Completed 28 out of 35 links of Page 210
# Completed 29 out of 35 links of Page 210
# Completed 30 out of 35 links of Page 210
# Completed 31 out of 35 links of Page 210
# Completed 32 out of 35 links of Page 210
# Completed 33 out of 35 links of Page 210
# Completed 34 out of 35 links of Page 210
# Completed 35 out of 35 links of Page 210
# Next Page is  211
# 211
# Completed 1 out of 35 links of Page 211
# Completed 2 out of 35 links of Page 211
# Completed 3 out of 35 links of Page 211
# Completed 4 out of 35 links of Page 211
# Completed 5 out of 35 links of Page 211
# Completed 6 out of 35 links of Page 211
# Completed 7 out of 35 links of Page 211
# Completed 8 out of 35 links of Page 211
# Completed 9 out of 35 links of Page 211
# Completed 10 out of 35 links of Page 211
# Completed 11 out of 35 links of Page 211
# Completed 12 out of 35 links of Page 211
# Completed 13 out of 35 links of Page 211
# Completed 14 out of 35 links of Page 211
# Completed 15 out of 35 links of Page 211
# Completed 16 out of 35 links of Page 211
# Completed 17 out of 35 links of Page 211
# Completed 18 out of 35 links of Page 211
# Completed 19 out of 35 links of Page 211
# Completed 20 out of 35 links of Page 211
# Completed 21 out of 35 links of Page 211
# Completed 22 out of 35 links of Page 211
# Completed 23 out of 35 links of Page 211
# Completed 24 out of 35 links of Page 211
# Completed 25 out of 35 links of Page 211
# Completed 26 out of 35 links of Page 211
# Completed 27 out of 35 links of Page 211
# Completed 28 out of 35 links of Page 211
# Completed 29 out of 35 links of Page 211
# Completed 30 out of 35 links of Page 211
# Completed 31 out of 35 links of Page 211
# Completed 32 out of 35 links of Page 211
# Completed 33 out of 35 links of Page 211
# Completed 34 out of 35 links of Page 211
# Completed 35 out of 35 links of Page 211
# Next Page is  212
# 212
# Completed 1 out of 35 links of Page 212
# Completed 2 out of 35 links of Page 212
# Completed 3 out of 35 links of Page 212
# Completed 4 out of 35 links of Page 212
# Completed 5 out of 35 links of Page 212
# Completed 6 out of 35 links of Page 212
# Completed 7 out of 35 links of Page 212
# Completed 8 out of 35 links of Page 212
# Completed 9 out of 35 links of Page 212
# Completed 10 out of 35 links of Page 212
# Completed 11 out of 35 links of Page 212
# Completed 12 out of 35 links of Page 212
# Completed 13 out of 35 links of Page 212
# Completed 14 out of 35 links of Page 212
# Completed 15 out of 35 links of Page 212
# Completed 16 out of 35 links of Page 212
# Completed 17 out of 35 links of Page 212
# Completed 18 out of 35 links of Page 212
# Completed 19 out of 35 links of Page 212
# Completed 20 out of 35 links of Page 212
# Completed 21 out of 35 links of Page 212
# Completed 22 out of 35 links of Page 212
# Completed 23 out of 35 links of Page 212
# Completed 24 out of 35 links of Page 212
# Completed 25 out of 35 links of Page 212
# Completed 26 out of 35 links of Page 212
# Completed 27 out of 35 links of Page 212
# Completed 28 out of 35 links of Page 212
# Completed 29 out of 35 links of Page 212
# Completed 30 out of 35 links of Page 212
# Completed 31 out of 35 links of Page 212
# Completed 32 out of 35 links of Page 212
# Completed 33 out of 35 links of Page 212
# Completed 34 out of 35 links of Page 212
# Completed 35 out of 35 links of Page 212
# Next Page is  213
# 213
# Completed 1 out of 35 links of Page 213
# Completed 2 out of 35 links of Page 213
# Completed 3 out of 35 links of Page 213
# Completed 4 out of 35 links of Page 213
# Completed 5 out of 35 links of Page 213
# Completed 6 out of 35 links of Page 213
# Completed 7 out of 35 links of Page 213
# Completed 8 out of 35 links of Page 213
# Completed 9 out of 35 links of Page 213
# Completed 10 out of 35 links of Page 213
# Completed 11 out of 35 links of Page 213
# Completed 12 out of 35 links of Page 213
# Completed 13 out of 35 links of Page 213
# Completed 14 out of 35 links of Page 213
# Completed 15 out of 35 links of Page 213
# Completed 16 out of 35 links of Page 213
# Completed 17 out of 35 links of Page 213
# Completed 18 out of 35 links of Page 213
# Completed 19 out of 35 links of Page 213
# Completed 20 out of 35 links of Page 213
# Completed 21 out of 35 links of Page 213
# Completed 22 out of 35 links of Page 213
# Completed 23 out of 35 links of Page 213
# Completed 24 out of 35 links of Page 213
# Completed 25 out of 35 links of Page 213
# Completed 26 out of 35 links of Page 213
# Completed 27 out of 35 links of Page 213
# Completed 28 out of 35 links of Page 213
# Completed 29 out of 35 links of Page 213
# Completed 30 out of 35 links of Page 213
# Completed 31 out of 35 links of Page 213
# Completed 32 out of 35 links of Page 213
# Completed 33 out of 35 links of Page 213
# Completed 34 out of 35 links of Page 213
# Completed 35 out of 35 links of Page 213
# Next Page is  214
# 214
# Completed 1 out of 35 links of Page 214
# Completed 2 out of 35 links of Page 214
# Completed 3 out of 35 links of Page 214
# Completed 4 out of 35 links of Page 214
# Completed 5 out of 35 links of Page 214
# Completed 6 out of 35 links of Page 214
# Completed 7 out of 35 links of Page 214
# Completed 8 out of 35 links of Page 214
# Completed 9 out of 35 links of Page 214
# Completed 10 out of 35 links of Page 214
# Completed 11 out of 35 links of Page 214
# Completed 12 out of 35 links of Page 214
# Completed 13 out of 35 links of Page 214
# Completed 14 out of 35 links of Page 214
# Completed 15 out of 35 links of Page 214
# Completed 16 out of 35 links of Page 214
# Completed 17 out of 35 links of Page 214
# Completed 18 out of 35 links of Page 214
# Completed 19 out of 35 links of Page 214
# Completed 20 out of 35 links of Page 214
# Completed 21 out of 35 links of Page 214
# Completed 22 out of 35 links of Page 214
# Completed 23 out of 35 links of Page 214
# Completed 24 out of 35 links of Page 214
# Completed 25 out of 35 links of Page 214
# Completed 26 out of 35 links of Page 214
# Completed 27 out of 35 links of Page 214
# Completed 28 out of 35 links of Page 214
# Completed 29 out of 35 links of Page 214
# Completed 30 out of 35 links of Page 214
# Completed 31 out of 35 links of Page 214
# Completed 32 out of 35 links of Page 214
# Completed 33 out of 35 links of Page 214
# Completed 34 out of 35 links of Page 214
# Completed 35 out of 35 links of Page 214
# Next Page is  215
# 215
# Completed 1 out of 35 links of Page 215
# Completed 2 out of 35 links of Page 215
# Completed 3 out of 35 links of Page 215
# Completed 4 out of 35 links of Page 215
# Completed 5 out of 35 links of Page 215
# Completed 6 out of 35 links of Page 215
# Completed 7 out of 35 links of Page 215
# Completed 8 out of 35 links of Page 215
# Completed 9 out of 35 links of Page 215
# Completed 10 out of 35 links of Page 215
# Completed 11 out of 35 links of Page 215
# Completed 12 out of 35 links of Page 215
# Completed 13 out of 35 links of Page 215
# Completed 14 out of 35 links of Page 215
# Completed 15 out of 35 links of Page 215
# Completed 16 out of 35 links of Page 215
# Completed 17 out of 35 links of Page 215
# Completed 18 out of 35 links of Page 215
# Completed 19 out of 35 links of Page 215
# Completed 20 out of 35 links of Page 215
# Completed 21 out of 35 links of Page 215
# Completed 22 out of 35 links of Page 215
# Completed 23 out of 35 links of Page 215
# Completed 24 out of 35 links of Page 215
# Completed 25 out of 35 links of Page 215
# Completed 26 out of 35 links of Page 215
# Completed 27 out of 35 links of Page 215
# Completed 28 out of 35 links of Page 215
# Completed 29 out of 35 links of Page 215
# Completed 30 out of 35 links of Page 215
# Completed 31 out of 35 links of Page 215
# Completed 32 out of 35 links of Page 215
# Completed 33 out of 35 links of Page 215
# Completed 34 out of 35 links of Page 215
# Completed 35 out of 35 links of Page 215
# Next Page is  216
# 4
# Completed 1 out of 15 links of Page 4
# Completed 2 out of 15 links of Page 4
# Completed 3 out of 15 links of Page 4
# Completed 4 out of 15 links of Page 4
# Completed 5 out of 15 links of Page 4
# Completed 6 out of 15 links of Page 4
# Completed 7 out of 15 links of Page 4
# Completed 8 out of 15 links of Page 4
# Completed 9 out of 15 links of Page 4
# Completed 10 out of 15 links of Page 4
# Completed 11 out of 15 links of Page 4
# Completed 12 out of 15 links of Page 4
# Completed 13 out of 15 links of Page 4
# Completed 14 out of 15 links of Page 4
# Completed 15 out of 15 links of Page 4
# Next Page is  217
# 217
# Completed 1 out of 35 links of Page 217
# Completed 2 out of 35 links of Page 217
# Completed 3 out of 35 links of Page 217
# Completed 4 out of 35 links of Page 217
# Completed 5 out of 35 links of Page 217
# Completed 6 out of 35 links of Page 217
# Completed 7 out of 35 links of Page 217
# Completed 8 out of 35 links of Page 217
# Completed 9 out of 35 links of Page 217
# Completed 10 out of 35 links of Page 217
# Completed 11 out of 35 links of Page 217
# Completed 12 out of 35 links of Page 217
# Completed 13 out of 35 links of Page 217
# Completed 14 out of 35 links of Page 217
# Completed 15 out of 35 links of Page 217
# Completed 16 out of 35 links of Page 217
# Completed 17 out of 35 links of Page 217
# Completed 18 out of 35 links of Page 217
# Completed 19 out of 35 links of Page 217
# Completed 20 out of 35 links of Page 217
# Completed 21 out of 35 links of Page 217
# Completed 22 out of 35 links of Page 217
# Completed 23 out of 35 links of Page 217
# Completed 24 out of 35 links of Page 217
# Completed 25 out of 35 links of Page 217
# Completed 26 out of 35 links of Page 217
# Completed 27 out of 35 links of Page 217
# Completed 28 out of 35 links of Page 217
# Completed 29 out of 35 links of Page 217
# Completed 30 out of 35 links of Page 217
# Completed 31 out of 35 links of Page 217
# Completed 32 out of 35 links of Page 217
# Completed 33 out of 35 links of Page 217
# Completed 34 out of 35 links of Page 217
# Completed 35 out of 35 links of Page 217
# Next Page is  218
# 218
# Completed 1 out of 35 links of Page 218
# Completed 2 out of 35 links of Page 218
# Completed 3 out of 35 links of Page 218
# Completed 4 out of 35 links of Page 218
# Completed 5 out of 35 links of Page 218
# Completed 6 out of 35 links of Page 218
# Completed 7 out of 35 links of Page 218
# Completed 8 out of 35 links of Page 218
# Completed 9 out of 35 links of Page 218
# Completed 10 out of 35 links of Page 218
# Completed 11 out of 35 links of Page 218
# Completed 12 out of 35 links of Page 218
# Completed 13 out of 35 links of Page 218
# Completed 14 out of 35 links of Page 218
# Completed 15 out of 35 links of Page 218
# Completed 16 out of 35 links of Page 218
# Completed 17 out of 35 links of Page 218
# Completed 18 out of 35 links of Page 218
# Completed 19 out of 35 links of Page 218
# Completed 20 out of 35 links of Page 218
# Completed 21 out of 35 links of Page 218
# Completed 22 out of 35 links of Page 218
# Completed 23 out of 35 links of Page 218
# Completed 24 out of 35 links of Page 218
# Completed 25 out of 35 links of Page 218
# Completed 26 out of 35 links of Page 218
# Completed 27 out of 35 links of Page 218
# Completed 28 out of 35 links of Page 218
# Completed 29 out of 35 links of Page 218
# Completed 30 out of 35 links of Page 218
# Completed 31 out of 35 links of Page 218
# Completed 32 out of 35 links of Page 218
# Completed 33 out of 35 links of Page 218
# Completed 34 out of 35 links of Page 218
# Completed 35 out of 35 links of Page 218
# Next Page is  219
# 219
# Completed 1 out of 35 links of Page 219
# Completed 2 out of 35 links of Page 219
# Completed 3 out of 35 links of Page 219
# Completed 4 out of 35 links of Page 219
# Completed 5 out of 35 links of Page 219
# Completed 6 out of 35 links of Page 219
# Completed 7 out of 35 links of Page 219
# Completed 8 out of 35 links of Page 219
# Completed 9 out of 35 links of Page 219
# Completed 10 out of 35 links of Page 219
# Completed 11 out of 35 links of Page 219
# Completed 12 out of 35 links of Page 219
# Completed 13 out of 35 links of Page 219
# Completed 14 out of 35 links of Page 219
# Completed 15 out of 35 links of Page 219
# Completed 16 out of 35 links of Page 219
# Completed 17 out of 35 links of Page 219
# Completed 18 out of 35 links of Page 219
# Completed 19 out of 35 links of Page 219
# Completed 20 out of 35 links of Page 219
# Completed 21 out of 35 links of Page 219
# Completed 22 out of 35 links of Page 219
# Completed 23 out of 35 links of Page 219
# Completed 24 out of 35 links of Page 219
# Completed 25 out of 35 links of Page 219
# Completed 26 out of 35 links of Page 219
# Completed 27 out of 35 links of Page 219
# Completed 28 out of 35 links of Page 219
# Completed 29 out of 35 links of Page 219
# Completed 30 out of 35 links of Page 219
# Completed 31 out of 35 links of Page 219
# Completed 32 out of 35 links of Page 219
# Completed 33 out of 35 links of Page 219
# Completed 34 out of 35 links of Page 219
# Completed 35 out of 35 links of Page 219
# Next Page is  220
# 220
# Completed 1 out of 35 links of Page 220
# Completed 2 out of 35 links of Page 220
# Completed 3 out of 35 links of Page 220
# Completed 4 out of 35 links of Page 220
# Completed 5 out of 35 links of Page 220
# Completed 6 out of 35 links of Page 220
# Completed 7 out of 35 links of Page 220
# Completed 8 out of 35 links of Page 220
# Completed 9 out of 35 links of Page 220
# Completed 10 out of 35 links of Page 220
# Completed 11 out of 35 links of Page 220
# Completed 12 out of 35 links of Page 220
# Completed 13 out of 35 links of Page 220
# Completed 14 out of 35 links of Page 220
# Completed 15 out of 35 links of Page 220
# Completed 16 out of 35 links of Page 220
# Completed 17 out of 35 links of Page 220
# Completed 18 out of 35 links of Page 220
# Completed 19 out of 35 links of Page 220
# Completed 20 out of 35 links of Page 220
# Completed 21 out of 35 links of Page 220
# Completed 22 out of 35 links of Page 220
# Completed 23 out of 35 links of Page 220
# Completed 24 out of 35 links of Page 220
# Completed 25 out of 35 links of Page 220
# Completed 26 out of 35 links of Page 220
# Completed 27 out of 35 links of Page 220
# Completed 28 out of 35 links of Page 220
# Completed 29 out of 35 links of Page 220
# Completed 30 out of 35 links of Page 220
# Completed 31 out of 35 links of Page 220
# Completed 32 out of 35 links of Page 220
# Completed 33 out of 35 links of Page 220
# Completed 34 out of 35 links of Page 220
# Completed 35 out of 35 links of Page 220
# Next Page is  221
# 221
# Completed 1 out of 35 links of Page 221
# Completed 2 out of 35 links of Page 221
# Completed 3 out of 35 links of Page 221
# Completed 4 out of 35 links of Page 221
# Completed 5 out of 35 links of Page 221
# Completed 6 out of 35 links of Page 221
# Completed 7 out of 35 links of Page 221
# Completed 8 out of 35 links of Page 221
# Completed 9 out of 35 links of Page 221
# Completed 10 out of 35 links of Page 221
# Completed 11 out of 35 links of Page 221
# Completed 12 out of 35 links of Page 221
# Completed 13 out of 35 links of Page 221
# Completed 14 out of 35 links of Page 221
# Completed 15 out of 35 links of Page 221
# Completed 16 out of 35 links of Page 221
# Completed 17 out of 35 links of Page 221
# Completed 18 out of 35 links of Page 221
# Completed 19 out of 35 links of Page 221
# Completed 20 out of 35 links of Page 221
# Completed 21 out of 35 links of Page 221
# Completed 22 out of 35 links of Page 221
# Completed 23 out of 35 links of Page 221
# Completed 24 out of 35 links of Page 221
# Completed 25 out of 35 links of Page 221
# Completed 26 out of 35 links of Page 221
# Completed 27 out of 35 links of Page 221
# Completed 28 out of 35 links of Page 221
# Completed 29 out of 35 links of Page 221
# Completed 30 out of 35 links of Page 221
# Completed 31 out of 35 links of Page 221
# Completed 32 out of 35 links of Page 221
# Completed 33 out of 35 links of Page 221
# Completed 34 out of 35 links of Page 221
# Completed 35 out of 35 links of Page 221
# Next Page is  222
# 222
# Completed 1 out of 35 links of Page 222
# Completed 2 out of 35 links of Page 222
# Completed 3 out of 35 links of Page 222
# Completed 4 out of 35 links of Page 222
# Completed 5 out of 35 links of Page 222
# Completed 6 out of 35 links of Page 222
# Completed 7 out of 35 links of Page 222
# Completed 8 out of 35 links of Page 222
# Completed 9 out of 35 links of Page 222
# Completed 10 out of 35 links of Page 222
# Completed 11 out of 35 links of Page 222
# Completed 12 out of 35 links of Page 222
# Completed 13 out of 35 links of Page 222
# Completed 14 out of 35 links of Page 222
# Completed 15 out of 35 links of Page 222
# Completed 16 out of 35 links of Page 222
# Completed 17 out of 35 links of Page 222

# %%
#drop duplicate
scraped_df = scraped_df.drop_duplicates()
scraped_df.to_csv('scraped_df3.csv', index=False)
